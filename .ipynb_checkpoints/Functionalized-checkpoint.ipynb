# %% [markdown]
# # NZ Seek Data Jobs Analysis

# %% [markdown]
# ## Data Reprocessing

# %% [markdown]
# ### 1. Import library

# %%
import pandas as pd
import numpy as np
import re

pd.set_option('display.max_colwidth',-1)

# %%
Dict_title_index = {'Admin':0}
Dict_company_index = {'Admin':2}
Dict_seek_index = {'Admin':1}
Dict_post_index = {'Admin':4}
Dict_location_index = {'Admin':3}
Dict_classification_index = {'Admin':5}

# %% [markdown]
# ### 2. Values

# %% [markdown]
# ### 2-0 Help function

# %%
# Function to clean duplicated text
def delduplicated(x):
    sentence=x.strip()
    index=(sentence+sentence).find(sentence,1)
    if index!=-1:
        return sentence[:index]
    else:
        return 'Unknown'
    
# Function to get salary from classification col
def detect_salary(df,class_index):
    for index,row in enumerate(df[class_index]):
        if 'classification:' in row:
            df.loc[index,'Salary'] = 'Unknown'
        else:
            df.loc[index,'Salary'] = row
            df.loc[index,class_index]='Unknown'
    return df['Salary']
    
# Unify post time 
def time_transfer(x):
    if 'd' in x:
        return -int(x[:-1])
    elif 'm' in x:
        return -(int(x[:-1])*30)
    elif x =='Unknown':
        return 'Unknown'
    else:
        return 0
    
# Function using to compare min_salary and max_salary for telling which should include k value
def tell_k_value(df):
    if (df['Max_salary']/df['Min_salary'])>=1000:
        df['Min_salary'] = df['Min_salary']*1000
    return df

# %% [markdown]
# ### 2-1 Get possible useful info from url

# %%
def seek_link(df,seek_index):
    df[["Job_ID","Search_Type"]]=df[seek_index].str.extract('job/(.+?)?type=(\w+)',expand=True) 
    df['Job_ID'] = df['Job_ID'].str.replace('?','').astype(int)
    df.drop([seek_index],axis=1,inplace=True)
    return df

# %% [markdown]
# ### 2-2 Get post time

# %%
### Clean Original post_time,get job's posted time
def get_postime(df, post_index):
    df[['Post_Time(h)','Featured_at']]=df[post_index].str.split(',',expand=True)[[0,2]]
#     df.drop(['Featured_at'],axis=1,inplace=True)
    df['Post_Time(h)']=df['Post_Time(h)'].str.extract('(\d+\w)')
    df['Post_Time(h)'].fillna('Unknown',inplace=True)
    df['Post_Time(h)']=df['Post_Time(h)'].astype('str')
    df['Post_Time(h)']=df['Post_Time(h)'].apply(time_transfer)
    df.drop([post_index],axis=1,inplace=True)
    return df

# %% [markdown]
# ### 2-3 Get Location and Area

# %%
# Clean Original location info, get location and area info
def clean_location(df,location_index):
    df[['Location','Area']]=df[location_index].str.split('area: ',expand=True)
    df['Area']=df['Area'].str.split(',',expand=True)[0]
    
    df['Location'] = [x[10:] for x in df['Location']]
    df['Location'] = df['Location'].apply(delduplicated)
    
    df['Area'].fillna('Unknown',inplace=True)
    df['Area'] = df['Area'].apply(delduplicated)
    
    df.drop([location_index],axis=1,inplace=True)
    return df

# %% [markdown]
# ### 2-4 Get Classification and subclassification

# %%
# Get classification and sub from classification col
def clean_classification(df,class_index):
#     get salary from classification col
    df['Salary'] = detect_salary(df,class_index)
# clean classification and subclassi
    df[['Classification','Subclassification']]=df[class_index].str.split('subClassification: ',expand=True)
    df['Classification'] = [x[16:] for x in df['Classification']]
    
    df['Classification']=df['Classification'].apply(delduplicated)

    df['Subclassification'].fillna('Unknown',inplace=True)
    df['Subclassification']=df['Subclassification'].apply(delduplicated)
    
    df.drop([class_index],axis=1,inplace=True)
    return df

# %% [markdown]
# ### 2-5 Get Salary

# %%
def clean_salary(df):

    # get holiday pay
    df['Plus']=df['Salary'].str.extract('(\d+%)')
    df['Plus'].fillna('Unkown',inplace=True)

    df['Salary']= df[df['Salary'].str.contains('\d')]['Salary'].str.replace('to','-')
    df['Salary']=df[df['Salary'].str.contains('\d',na=False)]['Salary'].str.replace('\d+%','',regex=True)
    
    #split range from salary
    df[['Min_salary','Max_salary']]=df['Salary'].str.split('-',n=1,expand=True).fillna('Unkown')
    df[['Min_salary','Max_salary']].fillna('Unkown',inplace=True)
    
    # clean min and max salary, unify format
    df['Min_salary'] = df['Min_salary'].str.replace(',','')
    df['Max_salary'] = df['Max_salary'].str.replace(',','')
    
    # extract salary num having '. k ' and remove space between num
    df['Min_salary'] = df['Min_salary'].str.extract('(\d+\.\+\d|\d+ \d+|\d+[kK]|\d+)')
    df['Max_salary'] = df['Max_salary'].str.extract('(\d+\.\+\d|\d+ \d+|\d+[kK]|\d+)')
    df['Min_salary'] = df['Min_salary'].str.replace(' ','')
    df['Max_salary'] = df['Max_salary'].str.replace(' ','')
    
    # get the indexes of num which having 'k' from max col 
    # replace k to 000 in both min/max cols
    df['Max_salary']=df[df['Max_salary'].str.contains('\d',na=False)]['Max_salary'].str.replace('k|K','000',regex=True)
    df['Min_salary']=df[df['Min_salary'].str.contains('\d',na=False)]['Min_salary'].str.replace('k|K','000',regex=True)

    df['Min_salary']=df['Min_salary'].fillna('Unkown')
    df['Max_salary']=df['Max_salary'].fillna('Unkown')
    
    # to fulfill null salary in min/max salary col
    for i, row in enumerate(df['Min_salary']):
        if row=='Unkown':
            df.loc[i,'Min_salary']=np.random.randint(45000,75000,size=1)[0]
            
    for i, row in enumerate(df['Max_salary']):
        if row=='Unkown':
            df.loc[i,'Max_salary']=max(np.random.randint(45000,75000,size=1)[0],float(df['Min_salary'][i]))
            
            
    # Unify min/max salary cols values' format 
    df['Min_salary']=df['Min_salary'].astype('float32')
    df['Max_salary']=df['Max_salary'].astype('float32')
    
    #find salary including k and unify min/max salarys with k
    df['Min_salary']=df.apply(tell_k_value,axis=1)['Min_salary']
    
    # add holiday pay plus to each job's salary needed
    for i, row in enumerate(df['Plus']):
        if row != 'Unkown':
            df.loc[i,'Min_salary']=(float(df['Plus'][i][:-1])/100)*df.loc[i,'Min_salary']
            df.loc[i,'Max_salary']=(float(df['Plus'][i][:-1])/100)*df.loc[i,'Max_salary']
     
    # transfer min/max salary cols into annual base value
    df.loc[(df['Min_salary']/100)<=10,'Min_salary']=df['Min_salary']*8*200
    df.loc[(df['Max_salary']/100)<=10,'Max_salary']=df['Max_salary']*8*200
    
    
    # Delete redundant cols
    df.drop(['Salary'],axis=1,inplace=True)
    df.drop(['Plus'],axis=1,inplace=True)
    
    return df

# %% [markdown]
# ### 2-6 Rename other cols and fulfill company col with 'Featured at' col

# %%
def rename_col(df,title_index,company_index):
    df.rename(columns={title_index:'Job_Title',company_index:'Company'},inplace=True)
    df['Company'].fillna(df['Featured_at'],inplace=True)
    df.drop(['Featured_at'],axis=1,inplace=True)
    
    return df

# %% [markdown]
# ## 3. Main function

# %%
def clean_jobfile(path,job_filename):
    df = pd.read_excel(path,header=None, skiprows=1)
    df = seek_link(df,Dict_seek_index[job_filename])
    df = get_postime(df,Dict_post_index[job_filename])
    df = clean_location(df,Dict_location_index[job_filename])
    df = clean_classification(df,Dict_classification_index[job_filename])
    df = clean_salary(df)
    df = rename_col(df,Dict_title_index[job_filename],Dict_company_index[job_filename])
    return df

# %%
df_admin = clean_jobfile('NZ_Admin_JOBS.xlsx','Admin')

# %%
df_admin
# Out:
#                                                             Job_Title  \
# 0     Administrator
# 1     Receptionist
# 2     Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4     Business Support Administrator
# 5     Support Officer
# 6     Support Officer
# 7     office administrator
# 8     Office Administrator
# 9     Administration Officer
# 10    Administration Officer
# 11    Data Entry
# 12    Office Admin Assistant (10hrs per week)
# 13    Office Administrator
# 14    Office Administrator
# 15    Customer Service Officer
# 16    Administration Assistant - Mt Wellington
# 17    Part-time Health & Disability Administrative Assistant
# 18    Office Coordinator, Whangarei Youth Space
# 19    Administrator
# 20    Administration Officer - Part Time
# 21    Part-time Admin/Accounts Person
# 22    Business Support Administrator
# 23    Reception/Administrator
# 24    Office Co-Ordinator
# 25    Office Administrator
# 26    Administration & Customer Service
# 27    Administrator
# 28    RECEPTIONIST / ADMINISTRATOR
# 29    Administrator - Street to Home
# ...                              ...
# 2678  Executive Assistant
# 2679  Register your CV with Personnel Resources / Temp Resources
# 2680  Contracts Administrator
# 2681  Customer Service & Sales Support
# 2682  Experienced Executive & Personal Assistants
# 2683  Temporary Office Roles
# 2684  Team Administrator
# 2685  Executive Assistant
# 2686  Sales Administrator and Support
# 2687  Resource Coordinator - Construction (plant, material, supplies)
# 2688  Customer Service and Sales Support
# 2689  Experienced Administrator
# 2690  Category Manager
# 2691  Administrator - Temps
# 2692  Temp Receptionists/Administrators - Ad Agencies/Music Companies
# 2693  Graduates with Office Administration Experience!
# 2694  On-site Manager
# 2695  Business Professional - Temporary Opportunities
# 2696  Seeking Executive Support Candidates
# 2697  PA / Team Administrators
# 2698  Temporary Service Coordinator
# 2699  Senior Executive Assistant
# 2700  Executive Assistant
# 2701  Temporary Office Roles
# 2702  Document Controller - Waikeria
# 2703  Key Account Manager
# 2704  Executive Assistant
# 2705  Temporary Office Roles
# 2706  Temporary Office Roles
# 2707  Executive Assistant
#
#                                                                           Company  \
# 0     Private Advertiser
# 1     Avenues Orthodontics
# 2     New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4     Private Advertiser
# 5     Ministry for Primary Industries
# 6     Ministry of Business, Innovation and Employment
# 7     Hepburn Electrical Ltd
# 8     Webster Holland Ltd
# 9     New Zealand Police
# 10    Department of Conservation
# 11    Triple One Care
# 12    UIV Limited - Premier Insulation North Central
# 13    Wraight and Associates Ltd.
# 14    Morgan & Pollard Landscapes Ltd
# 15    CM Trailer Parts
# 16    Harvey Norman
# 17    LIFEWISE
# 18    Whangarei Youth Space
# 19    Private Advertiser
# 20    HiFlo Pumps Ltd
# 21    People Passion
# 22    S&L Land Development and Design Specialists
# 23    Fishing and Leisure Group Limited
# 24    Paeroa Farm Services Ltd
# 25    Brant Homes Limited
# 26    ACE
# 27    EnviroWaste Services Limited
# 28    PROGRESSIVE MEATS LIMITED
# 29    Auckland City Mission
# ...                     ...
# 2678  Alpha Recruitment - NZ
# 2679  Personnel Resources/Temp Resources
# 2680  X4 Construction
# 2681  JOYN
# 2682  GBL Personnel
# 2683  Asset Recruitment Ltd
# 2684  Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# 2685  Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# 2686  Uniform Group (Auckland) Ltd
# 2687  Piritahi
# 2688  Wellfit-Wstar
# 2689  Adecco Office
# 2690  Bidfood
# 2691  Recruitment Studio
# 2692  Metro Recruitment Ltd
# 2693  GBL Personnel
# 2694  Stonewood Group Ltd
# 2695  Enterprise Recruitment
# 2696  GBL Personnel
# 2697  Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# 2698  Graham Consulting
# 2699  Beyond Recruitment - Winner – Best Innovation –2018 Global Recruiter Awards
# 2700  Robert Walters
# 2701  Asset Recruitment Ltd
# 2702  Stellar Recruitment
# 2703  Hays Talent Solutions
# 2704  one eighty recruitment
# 2705  Asset Recruitment Ltd
# 2706  Asset Recruitment Ltd
# 2707  Alpha Recruitment - NZ
#
#         Job_ID Search_Type Post_Time(h)  \
# 0     50582301  promoted    Unknown
# 1     50620889  promoted    Unknown
# 2     50622169  standard    -4
# 3     50639620  standard    0
# 4     50622432  standout    -4
# 5     50640393  standout    -270
# 6     50615674  standout    -5
# 7     50640166  standard    -210
# 8     50639248  standard    0
# 9     50629393  standard    -3
# 10    50600186  standout    -7
# 11    50616188  standard    -5
# 12    50597141  standard    -8
# 13    50632818  standard    -3
# 14    50632185  standout    -3
# 15    50614282  standout    -5
# 16    50638817  standout    0
# 17    50610748  standout    -6
# 18    50633756  standard    -3
# 19    50604829  standard    -7
# 20    50637525  standout    -2
# 21    50631111  standout    -3
# 22    50591178  promoted    Unknown
# 23    50556340  promoted    Unknown
# 24    50632905  standard    -3
# 25    50621389  standard    -4
# 26    50637747  standard    -2
# 27    50631960  standout    -3
# 28    50636107  standout    -3
# 29    50638937  standout    0
# ...        ...       ...   ..
# 2678  50496571  standout    -26
# 2679  50512721  standard    -24
# 2680  50490283  standard    -27
# 2681  50501057  standout    -25
# 2682  50625980  standout    -4
# 2683  50597464  standout    -7
# 2684  50475507  standout    -30
# 2685  50508497  standard    -24
# 2686  50482675  standout    -28
# 2687  50487373  standout    -27
# 2688  50490247  standout    -27
# 2689  50490876  standard    -27
# 2690  50524687  standout    -20
# 2691  50478359  standout    -28
# 2692  50488787  standard    -27
# 2693  50481639  standout    -28
# 2694  50481773  standard    -28
# 2695  50482020  standout    -28
# 2696  50504568  standout    -25
# 2697  50494221  standard    -26
# 2698  50518469  standout    -21
# 2699  50494425  standard    -26
# 2700  50494228  standout    -26
# 2701  50556279  standout    -14
# 2702  50486421  standard    -27
# 2703  50490062  standout    -27
# 2704  50488000  standout    -27
# 2705  50524865  standout    -20
# 2706  50477118  standout    -28
# 2707  50496571  standout    -26
#
#                                           Location                       Area  \
# 0     Bay of Plenty                                 Tauranga
# 1     Bay of Plenty                                 Tauranga
# 2     Auckland                                      Unknown
# 3     Southland                                     Invercargill
# 4     Canterbury                                    Christchurch
# 5     Northland                                     Whangarei
# 6     Wellington                                    Wellington Central
# 7     Bay of Plenty                                 Rotorua
# 8     Bay of Plenty                                 Tauranga
# 9     Canterbury                                    Unknown
# 10    West Coast                                    Rest of West Coast
# 11    Tasman                                        Nelson
# 12    Auckland                                      Manukau & East Auckland
# 13    Wellington                                    Wellington Central
# 14    Canterbury                                    Rest of Canterbury
# 15    Canterbury                                    Timaru & South Canterbury
# 16    Auckland                                      Auckland Central
# 17    Auckland                                      Auckland Central
# 18    Northland                                     Whangarei
# 19    Manawatu                                      Rest of Manawatu
# 20    Auckland                                      Auckland Central
# 21    Auckland                                      Papakura & Franklin
# 22    Bay of Plenty                                 Tauranga
# 23    Auckland                                      Rodney & North Shore
# 24    Waikato                                       Rest of Waikato
# 25    Auckland                                      Manukau & East Auckland
# 26    Auckland                                      Auckland Central
# 27    Canterbury                                    Christchurch
# 28    Hawkes Bay                                    Hastings
# 29    Auckland                                      Auckland Central
# ...        ...                                                   ...
# 2678  Wellington                                    Unknown
# 2679  Bay of Plenty                                 Rotorua
# 2680  Northland                                     Rest of Northland
# 2681  Manawatu                                      Rest of Manawatu
# 2682  Wellington                                    Wellington Central
# 2683  Waikato                                       Hamilton
# 2684  Auckland                                      Auckland Central
# 2685  Wellington                                    Unknown
# 2686  Auckland                                      Auckland Central
# 2687  Auckland                                      Auckland Central
# 2688  Auckland                                      Auckland Central
# 2689  Canterbury                                    Christchurch
# 2690  Auckland                                      Auckland Central
# 2691  Auckland                                      Auckland Central
# 2692  Auckland                                      Auckland Central
# 2693  Wellington                                    Unknown
# 2694  Wellington                                    Wellington Central
# 2695  Canterbury                                    Christchurch
# 2696  Wellington                                    Unknown
# 2697  Wellington                                    Unknown
# 2698  Auckland                                      Auckland Central
# 2699  Wellington                                    Unknown
# 2700  WellingtonWellington,Attractive remuneration  Unknown
# 2701  Waikato                                       Hamilton
# 2702  Waikato                                       Rest of Waikato
# 2703  Auckland                                      Auckland Central
# 2704  Wellington                                    Wellington Central
# 2705  Waikato                                       Hamilton
# 2706  Waikato                                       Hamilton
# 2707  Wellington                                    Unknown
#
#                        Classification                      Subclassification  \
# 0     Administration & Office Support  Office Management
# 1     Administration & Office Support  Receptionists
# 2     Administration & Office Support  Other
# 3     Administration & Office Support  Administrative Assistants
# 4     Administration & Office Support  Client & Sales Administration
# 5     Administration & Office Support  Administrative Assistants
# 6     Administration & Office Support  Other
# 7     Administration & Office Support  Administrative Assistants
# 8     Administration & Office Support  Administrative Assistants
# 9     Administration & Office Support  Other
# 10    Administration & Office Support  Administrative Assistants
# 11    Administration & Office Support  Data Entry & Word Processing
# 12    Unknown                          Unknown
# 13    Administration & Office Support  Office Management
# 14    Administration & Office Support  Administrative Assistants
# 15    Administration & Office Support  Client & Sales Administration
# 16    Administration & Office Support  Administrative Assistants
# 17    Unknown                          Unknown
# 18    Administration & Office Support  Administrative Assistants
# 19    Administration & Office Support  Other
# 20    Administration & Office Support  Administrative Assistants
# 21    Administration & Office Support  Administrative Assistants
# 22    Administration & Office Support  Administrative Assistants
# 23    Unknown                          Unknown
# 24    Administration & Office Support  Office Management
# 25    Unknown                          Unknown
# 26    Administration & Office Support  Administrative Assistants
# 27    Administration & Office Support  Administrative Assistants
# 28    Administration & Office Support  Administrative Assistants
# 29    Administration & Office Support  Administrative Assistants
# ...                               ...                        ...
# 2678  Administration & Office Support  PA, EA & Secretarial
# 2679  Administration & Office Support  Administrative Assistants
# 2680  Administration & Office Support  Contracts Administration
# 2681  Administration & Office Support  Client & Sales Administration
# 2682  Administration & Office Support  PA, EA & Secretarial
# 2683  Unknown                          Unknown
# 2684  Administration & Office Support  Administrative Assistants
# 2685  Administration & Office Support  PA, EA & Secretarial
# 2686  Administration & Office Support  Client & Sales Administration
# 2687  Administration & Office Support  Administrative Assistants
# 2688  Administration & Office Support  Client & Sales Administration
# 2689  Administration & Office Support  Administrative Assistants
# 2690  Administration & Office Support  Other
# 2691  Unknown                          Unknown
# 2692  Administration & Office Support  Receptionists
# 2693  Administration & Office Support  Administrative Assistants
# 2694  Administration & Office Support  Receptionists
# 2695  Administration & Office Support  Office Management
# 2696  Administration & Office Support  Administrative Assistants
# 2697  Administration & Office Support  PA, EA & Secretarial
# 2698  Administration & Office Support  Administrative Assistants
# 2699  Administration & Office Support  PA, EA & Secretarial
# 2700  Unknown                          Unknown
# 2701  Unknown                          Unknown
# 2702  Administration & Office Support  Records Management & Document Control
# 2703  Administration & Office Support  Client & Sales Administration
# 2704  Unknown                          Unknown
# 2705  Unknown                          Unknown
# 2706  Unknown                          Unknown
# 2707  Administration & Office Support  PA, EA & Secretarial
#
#       Min_salary  Max_salary
# 0     65358.0     65358.0
# 1     65537.0     67718.0
# 2     63497.0     63497.0
# 3     57483.0     74703.0
# 4     47079.0     47808.0
# 5     69130.0     72539.0
# 6     68792.0     68792.0
# 7     56021.0     56021.0
# 8     69107.0     74842.0
# 9     57191.0     57191.0
# 10    51333.0     51333.0
# 11    73386.0     73386.0
# 12    20000.0     67751.0
# 13    64552.0     64552.0
# 14    67718.0     67718.0
# 15    60768.0     60768.0
# 16    49825.0     61829.0
# 17    32000.0     38400.0
# 18    58333.0     72552.0
# 19    48282.0     56681.0
# 20    72679.0     72679.0
# 21    52403.0     52403.0
# 22    47337.0     67194.0
# 23    30400.0     35200.0
# 24    67443.0     67443.0
# 25    32000.0     38400.0
# 26    72620.0     72620.0
# 27    46363.0     46363.0
# 28    59308.0     59308.0
# 29    48498.0     56187.0
# ...       ...         ...
# 2678  72662.0     72662.0
# 2679  65415.0     65415.0
# 2680  57742.0     65517.0
# 2681  70152.0     70152.0
# 2682  58711.0     58711.0
# 2683  64611.0     64611.0
# 2684  51430.0     73418.0
# 2685  48835.0     51388.0
# 2686  55506.0     69415.0
# 2687  71758.0     71758.0
# 2688  59468.0     67227.0
# 2689  63020.0     74340.0
# 2690  70737.0     70737.0
# 2691  47709.0     47709.0
# 2692  55626.0     55626.0
# 2693  54405.0     66037.0
# 2694  60925.0     60925.0
# 2695  61230.0     69578.0
# 2696  74500.0     74500.0
# 2697  71240.0     71240.0
# 2698  59471.0     69932.0
# 2699  69784.0     69784.0
# 2700  57060.0     57060.0
# 2701  63807.0     63807.0
# 2702  56926.0     58704.0
# 2703  48874.0     48874.0
# 2704  55423.0     63752.0
# 2705  56457.0     56457.0
# 2706  62753.0     72263.0
# 2707  60142.0     60142.0
#
# [2708 rows x 11 columns]
